# %% [markdown]
# <a href="https://colab.research.google.com/github/dyou-wbg/meta_processing/blob/main/3IE_parsed_Check_Penal_Components.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
# as of today
import datetime as dt
dt.date.today()
import os
import pandas as pd
from google.colab import drive
import csv
import os
data_dir = '/content/drive/MyDrive/finalMetaFile'
files = os.listdir(data_dir)
# Out:
# Mounted at /content/drive

# %%
df2 = pd.read_csv('/content/drive/MyDrive/finalMetaFile/3ie_parsed_metadata.csv')
df2.head()
# Out:
#    Unnamed: 0  id                                              title  \
# 0           0   0  impacts of payments for ecosystem services pro...
# 1           1   1  providing collateral and improving product mar...
# 2           2   2  seeing is believing? evidence from an extensio...
# 3           3   3  smallholder access to weather securities in in...
# 4           4   4  sustainability of impact dimensions of decline...
#
#                                               author  \
# 0  Alix-Garcia, Jennifer; Aronson, Glen; Radeloff...
# 1  Casaburi, Lorenzo; Glennerster, Rachel; Suri, ...
# 2  Kondylis, Florence; Mueller, Valerie; Zhu, Siyao;
# 3  Ceballos, Francisco; R, Isaac Manuel; Robles, ...
# 4  Mcniven, Scott; Gilligan, Daniel O; Hotz, Chri...
#
#                                sector       country  \
# 0  Agriculture, fishing, and forestry        Mexico
# 1  Agriculture, fishing, and forestry  Sierra Leone
# 2  Agriculture, fishing, and forestry    Mozambique
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

pd.DataFrame(df2['method'].unique()).head(70)
# Out:
# <ipython-input-5-f2d733d76024>:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
#                                                                                                                                  0
# 0   ['Fixed effects estimation', 'Statistical matching']
# 1   ['Randomised controlled trial']
# 2   ['Randomised controlled trial', 'Difference-in-difference']
# 3   ['Difference-in-difference', 'Fixed effects estimation']
# 4   ['Difference-in-difference', 'Statistical matching']
# 5   ['Randomised controlled trial', 'Fixed effects estimation', 'Instrumental variable estimation']
# 6   ['Statistical matching']
# 7   ['Regression discontinuity design', 'Statistical matching']
# 8   ['Instrumental variable estimation']
# 9   ['Fixed effects estimation', 'Instrumental variable estimation']
# ...

# %%
import matplotlib.pyplot as plt

df_filtered = df2[df2['method'].fillna('NaN').str.contains('Randomised controlled trial')]

method_counts = df_filtered['method'].value_counts()

plt.figure().set_figheight(15)
plt.barh(method_counts.index, method_counts.values)
plt.xlabel('Number of studies')
plt.ylabel('Method')
plt.title('Distribution of studies with "Randomised controlled trial" in the "method" column')
plt.show()

# %%
df=df2[['title','abstract','method']]
# Out:
# Index(['Unnamed: 0', 'id', 'title', 'author', 'sector', 'country', 'URL', 'pub_time', 'pub',
#        'open_access', 'category', 'abstract', 'panels', 'source_url', 'pub_extr', 'pub_info',
#        'article_type', 'language', 'doi', 'journal', 'unit', 'method'],
#       dtype='object')

# %%
df_filtered = df2[df2['method'].fillna('NaN').str.contains('Randomised controlled trial', na=False)]
df_filtered = df_filtered[['title','abstract','method']]
df_filtered.head(30)
# Out:
#                                                                                                                                                                                                                        title  \
# 1    providing collateral and improving product market access for small holder farmers: a randomised evaluation of inventory credit in sierra leone
# 2    seeing is believing? evidence from an extension network experiment in mozambique
# 3    smallholder access to weather securities in india demand and impact on production decisions
# 4    sustainability of impact dimensions of decline and persistence in adopting a biofortified crop in uganda
# 6    assessing the impact of farmer field schools on fertiliser use in china
# 9    making networks work for policy: evidence from agricultural technology adoption in malawi
# 19   nudging farmers to use fertilizer: theory and experimental evidence from kenya
# ...

# %% [markdown]
# # 1. Title based classfication

# %%
import pandas as pd
df2['label'] = df2['method'].apply(lambda x: 1 if pd.notnull(x) and "Randomised controlled trial" in x else 0)
df_ready=df2[['title','abstract','label']]

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

# %%
import string

def preprocess_text(text):
  text = text.lower()
  text = ''.join([c for c in text if c not in string.punctuation])
  #text = ' '.join([word for word in text.split() if word not in stopwords.words('english')])
  return text

data =  df_ready
data["Text"] = data["title"].apply(preprocess_text)


vectorizer = TfidfVectorizer()
features = vectorizer.fit_transform(data["Text"])
# Out:
# <ipython-input-19-a8f5d1b8171e>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Text"] = data["title"].apply(preprocess_text)

# %%
X_train, X_test, y_train, y_test = train_test_split(features, data["label"], test_size=0.2)

# %%
clf = MultinomialNB()
clf.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.7572

# %% [markdown]
# # 2. Abstract based

# %%
data =  df_ready
data["Text"] = data["abstract"].fillna('NaN').apply(preprocess_text)

vectorizer = TfidfVectorizer()
features = vectorizer.fit_transform(data["Text"])
X_train, X_test, y_train, y_test = train_test_split(features, data["label"], test_size=0.2)
clf = MultinomialNB()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# <ipython-input-35-73fd76e5ab29>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Text"] = data["abstract"].fillna('NaN').apply(preprocess_text)
# Accuracy: 0.7301
