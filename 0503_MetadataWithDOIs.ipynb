# %% [markdown]
# <a href="https://colab.research.google.com/github/dyou-wbg/meta_processing/blob/main/0503_MetadataWithDOIs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
from google.colab import drive
import csv
import os
import re
import pandas as pd
import numpy as np

directory = '/content/drive/MyDrive/finalMetaFile'
df = pd.read_csv(os.path.join(directory, 'combined_metadata_final12_features.csv'))
#df=df[['sourcename', 'title']]
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <ipython-input-8-8c133cd4d91d>:12: DtypeWarning: Columns (1,2,3,4,5,7,9,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(directory, 'combined_metadata_final12_features.csv'))
#                                                title  doi documenttype  \
# 0  Economic Education in Our Schools: A Renewed M...  NaN      article
# 1                 Can Germany Contain Russia Safely?  NaN      article
# 2  Assessing the Impact of Sarbanes-Oxley Act on ...  NaN      article
# 3  Childhood Educational Disruption and Later Lif...  NaN      article
# 4          The Exclusion of Liability for Negligence  NaN      article
#
#   publisheddate                                                url  \
# 0    1984-10-01                http://www.jstor.org/stable/1182553
# ...

# %% [markdown]
# # Get title with DOIs

# %%
df_with_doi = df[df['doi'].notna()]
df_with_doi = df_with_doi[['title', 'doi']]
df_with_doi.head()
# Out:
#                                                      title  \
# 1095398  The marketing efficiency development to create...
# 1095399  Maritime knowledge clusters: A conceptual mode...
# 1095400  From “Communautaire Spirit” to the “Ghosts of ...
# 1095401                             The Economist's Corner
# 1095402  Tra rilancio e valutazione, le strategie di un...
#
#                                    doi
# 1095398     10.14505/jemt.v12.1(49).23
# 1095399   10.1016/j.marpol.2020.104299
# 1095400  10.1080/08911916.2017.1407737
# 1095401     10.1177/0148558X8600100309
# 1095402                 10.14650/86473

# %%
print({(len(df_with_doi)/len(df))},'%')
# Out:
# {0.464914875566867} %

# %%
proportion = (len(df_with_doi)/len(df)) * 100
print(f"proportion of available DOI is {proportion:.2f}% of entire dataset ")
# Out:
# proportion of available DOI is 46.49% of entire dataset

# %%
len(df_with_doi)
# Out:
# 5233570

# %%
df_with_doi = df[df['doi'].notna()]
df_with_doi.to_csv(os.path.join(directory, 'MetadataWithDOIs.csv'), index=False)
