# %% [markdown]
# <a href="https://colab.research.google.com/github/dyou-wbg/meta_processing/blob/main/meta_counting3_total_nine_metadata_sources.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
# as of today
import datetime as dt
dt.date.today()
import os
import pandas as pd
from google.colab import drive
# Out:
# Mounted at /content/drive

# %%
dt.date.today()
# Out:
# datetime.date(2024, 2, 21)

# %%
# Get the path to the directory containing the files
data_dir = '/content/drive/MyDrive/finalMetaFile'

# List all files in the directory
files = os.listdir(data_dir)
files
# Out:
# ['metadata_repec.tsv',
#  'metadata_jstor.csv',
#  'metadata_scopus 2.csv',
#  'elsevier_metadata.csv',
#  'metadata_semantic_scholar.csv',
#  'url1_ie_table_complete.csv',
#  'metadata_econlit.csv',
#  '.DS_Store',
#  'SSRN_metadata.csv',
#  'log.csv']

# %%
import csv
import os
data_dir = '/content/drive/MyDrive/finalMetaFile'
files = os.listdir(data_dir)

row_counts = {}
for filename in files:
  if filename.endswith('.csv') or filename.endswith('.tsv'):
    filepath = os.path.join(data_dir, filename)
    with open(filepath, 'r') as csvfile:
      reader = csv.reader(csvfile)
      row_count = sum(1 for row in reader)
      row_counts[filename] = row_count

for filename, row_count in row_counts.items():
  print(f'{filename}: {row_count}')
# Out:
# metadata_repec.tsv: 919765
# metadata_jstor.csv: 1095399
# metadata_scopus 2.csv: 711785
# elsevier_metadata.csv: 242411
# metadata_semantic_scholar.csv: 7912378
# url1_ie_table_complete.csv: 11378
# metadata_econlit.csv: 19122
# SSRN_metadata.csv: 99107
# log.csv: 30073

# %%
import openpyxl

# %%
import csv
import os


row_counts = {}
for filename in files:
  if filename.endswith('.csv') :
    filepath = os.path.join(data_dir, filename)
    print(filename)
    if filepath.endswith('.csv'):
      with open(filepath, 'r') as csvfile:
        reader = csv.reader(csvfile)
        row_count = sum(1 for row in reader)
        row_counts[filename] = row_count


for filename, row_count in row_counts.items():
  print(f'{filename}: {row_count}')
# Out:
# metadata_scopus 2.csv
# elsevier_metadata.csv
# metadata_semantic_scholar.csv
# url1_ie_table_complete.csv
# metadata_econlit.csv
# SSRN_metadata.csv
# metadata_scopus 2.csv: 711785
# elsevier_metadata.csv: 242411
# metadata_semantic_scholar.csv: 7912378
# url1_ie_table_complete.csv: 11378
# metadata_econlit.csv: 19122
# SSRN_metadata.csv: 99107

# %%
data = {'File Name': [], 'Row Count': []}

for filename in files:
  if filename.endswith('.csv') or filename.endswith('.tsv'):
    filepath = os.path.join(data_dir, filename)
    with open(filepath, 'r') as csvfile:
      reader = csv.reader(csvfile)
      row_count = sum(1 for row in reader)
      data['File Name'].append(filename)
      data['Row Count'].append(row_count)

df = pd.DataFrame(data)

df
# Out:
#                        File Name  Row Count
# 0             metadata_repec.tsv     919765
# 1             metadata_jstor.csv    1095399
# 2          metadata_scopus 2.csv     711785
# 3          elsevier_metadata.csv     242411
# 4  metadata_semantic_scholar.csv    7912378
# 5     url1_ie_table_complete.csv      11378
# 6           metadata_econlit.csv      19122
# 7              SSRN_metadata.csv      99107
# 8                        log.csv      30073

# %%
df.sort_values(['Row Count'])
# Out:
#                        File Name  Row Count
# 3     url1_ie_table_complete.csv      11378
# 4           metadata_econlit.csv      19122
# 5              SSRN_metadata.csv      99107
# 1          elsevier_metadata.csv     242411
# 0          metadata_scopus 2.csv     711785
# 2  metadata_semantic_scholar.csv    7912378

# %%
total_rows = df['Row Count'].sum()
print(f'Total number of rows in all files: {total_rows}')
# Out:
# Total number of rows in all files: 8996181

# %%
import csv
import os
data_dir = '/content/drive/MyDrive/all'
files = os.listdir(data_dir)

row_counts = {}
for filename in files:
  if  filename.endswith('.tsv'):
    filepath = os.path.join(data_dir, filename)
    with open(filepath, 'r') as csvfile:
      reader = csv.reader(csvfile)
      row_count = sum(1 for row in reader)
      row_counts[filename] = row_count
      data['File Name'].append(filename)
      data['Row Count'].append(row_count)

df1 = pd.DataFrame(data)

df1
# Out:
#                        File Name  Row Count
# 0          metadata_scopus 2.csv     711785
# 1          elsevier_metadata.csv     242411
# 2  metadata_semantic_scholar.csv    7912378
# 3     url1_ie_table_complete.csv      11378
# 4           metadata_econlit.csv      19122
# 5              SSRN_metadata.csv      99107
# 6             metadata_repec.tsv     919765
# 7             metadata_repec.tsv     919765

# %%
#df1[df1["File Name"] =='metadata_repec.tsv' ]
df1.iloc[[6]]
# Out:
#             File Name  Row Count
# 6  metadata_repec.tsv     919765

# %%
df.append(df1.iloc[[6]])
# Out:
# <ipython-input-23-54d58120d524>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(df1.iloc[[6]])
#                        File Name  Row Count
# 0          metadata_scopus 2.csv     711785
# 1          elsevier_metadata.csv     242411
# 2  metadata_semantic_scholar.csv    7912378
# 3     url1_ie_table_complete.csv      11378
# 4           metadata_econlit.csv      19122
# 5              SSRN_metadata.csv      99107
# 6             metadata_repec.tsv     919765
